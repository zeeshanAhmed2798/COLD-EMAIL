# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
print(os.getenv("MODEL_NAME"))
# Out:
# llama-3.3-70b-versatile

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key=os.getenv("GROQ_API_KEY"), 
    model_name=os.getenv("MODEL_NAME")
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader ("https://theaxiomworld.com/jobs/ml-ai-engineer-intern-159")
page_data=loader.load().pop().page_content
page_data
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nML/AI Engineer Intern | Axiom World\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDriving growth through innovation\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n0\n\nMy Cart\n\n\n\nSign in\n\n\n\n\n\n\n\n\n\nHome\n\n\n\n\nCourses\n\n\n\n\nJobs\n\n\n\n\nContact us\n\n\n\n\nPolicies\n\n\n\n\nCertification Expense Reimbursement Policy\n\n\n\n\nAttendance Policy\n\n\n\n\nAttendance and Leave Management SOP\n\n\n\n\nIT Equipment Policy\n\n\n\n\nEmployee Financial Assistance Policy\n\n\n\n\nPerformance Appraisal Policy \n\n\n\n\n\n\n\n\n\n\nContact Us\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n0\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\n\n\nCourses\n\n\n\n\nJobs\n\n\n\n\nContact us\n\n\n\n\nPolicies\n\n\n\n\nCertification Expense Reimbursement Policy\n\n\n\n\nAttendance Policy\n\n\n\n\nAttendance and Leave Management SOP\n\n\n\n\nIT Equipment Policy\n\n\n\n\nEmployee Financial Assistance Policy\n\n\n\n\nPerformance Appraisal Po
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
res.content
# Out:
# '```json\n{\n  "role": "ML/AI Engineer Intern",\n  "experience": "Intern",\n  "skills": [\n    "Machine Learning",\n    "AI",\n    "Python",\n    "Pandas",\n    "NumPy",\n    "Scikit-Learn",\n    "TensorFlow",\n    "PyTorch",\n    "HuggingFace",\n    "Langchain",\n    "Langgraph",\n    "Llama index",\n    "SpaCy",\n    "Gensim",\n    "Transformers",\n    "FastAPI"\n  ],\n  "description": "We are looking for a motivated and passionate Machine Learning Engineer Intern to join our dynamic and collaborative team. As an intern, you will have the opportunity to work on real-world machine learning projects, contribute to AI solutions, and gain hands-on experience in the development and deployment of machine learning models."\n}\n```'

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'ML/AI Engineer Intern',
#  'experience': 'Intern',
#  'skills': ['Machine Learning',
#   'AI',
#   'Python',
#   'Pandas',
#   'NumPy',
#   'Scikit-Learn',
#   'TensorFlow',
#   'PyTorch',
#   'HuggingFace',
#   'Langchain',
#   'Langgraph',
#   'Llama index',
#   'SpaCy',
#   'Gensim',
#   'Transformers',
#   'FastAPI'],
#  'description': 'We are looking for a motivated and passionate Machine Learning Engineer Intern to join our dynamic and collaborative team. As an intern, you will have the opportunity to work on real-world machine learning projects, contribute to AI solutions, and gain hands-on experience in the development and deployment of machine learning models.'}

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                   Techstack  \
# 0                   React, Node.js, MongoDB
# 1                 Angular, .NET, SQL Server
# 2         Vue.js, Ruby on Rails, PostgreSQL
# 3                     Python, Django, MySQL
# 4                 Java, Spring Boot, Oracle
# 5                Flutter, Firebase, GraphQL
# 6                     WordPress, PHP, MySQL
# 7                       Magento, PHP, MySQL
# 8            React Native, Node.js, MongoDB
# 9                     iOS, Swift, Core Data
# 10          Android, Java, Room Persistence
# 11                Kotlin, Android, Firebase
# 12          Android TV, Kotlin, Android NDK
# 13                        iOS, Swift, ARKit
# 14           Cross-platform, Xamarin, Azure
# 15             Backend, Kotlin, Spring Boot
# 16            Frontend, TypeScript, Angular
# 17       Full-stack, JavaScript, Express.js
# 18     Machine Learning, Python, TensorFlow
# 19                  DevOps, Jenkins, Docker
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# C:\Users\zeeshan_ahmed\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [01:16<00:00, 1.08MiB/s]

# %%
job=json_res
job['skills']
# Out:
# ['Machine Learning',
#  'AI',
#  'Python',
#  'Pandas',
#  'NumPy',
#  'Scikit-Learn',
#  'TensorFlow',
#  'PyTorch',
#  'HuggingFace',
#  'Langchain',
#  'Langgraph',
#  'Llama index',
#  'SpaCy',
#  'Gensim',
#  'Transformers',
#  'FastAPI']

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/deep-learning-portfolio'}],
#  [{'links': 'https://example.com/ai-engineer-portfolio'},
#   {'links': 'https://example.com/langchain-portfolio'}],
#  [{'links': 'https://example.com/data-science-portfolio'},
#   {'links': 'https://example.com/ai-engineer-portfolio'}],
#  [{'links': 'https://example.com/data-analyst-portfolio'},
#   {'links': 'https://example.com/data-science-portfolio'}],
#  [{'links': 'https://example.com/computer-vision-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/data-science-portfolio'},
#   {'links': 'https://example.com/ai-engineer-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/deep-learning-portfolio'}],
#  [{'links': 'https://example.com/ai-engineer-portfolio'},
#   {'links': 'https://example.com/computer-vision-portfolio'}],
# ...

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Zeeshan, a business development executive at zeeiom. zeeiom is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of zeeiom 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase zeeiom's portfolio: {link_list}
        Remember you are Zeeshan, BDE at zeeiom. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert ML/AI Engineer Intern Services for Your Business
#
# Dear Hiring Manager,
#
# I came across your job posting for an ML/AI Engineer Intern and was impressed by the exciting projects your team is working on. As a Business Development Executive at AtliQ, I'd like to introduce you to our company's capabilities in delivering top-notch AI and software consulting services.
#
# At AtliQ, we have a proven track record of empowering enterprises with tailored solutions, fostering scalability, process optimization, cost reduction, and heightened overall efficiency. Our team of experts has hands-on experience in developing and deploying machine learning models using Python, Pandas, NumPy, Scikit-Learn, TensorFlow, PyTorch, HuggingFace, Langchain, and other relevant technologies.
#
# I'd like to highlight some of our relevant portfolio work:
#
# * https://example.com/ml-python-portfolio
# * https://example.com/ai-engineer-portfolio
# * https://example.com/langchain-portfolio
# ...
